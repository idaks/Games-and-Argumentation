# %%
from gamearg import *
from IPython.display import display, Image

# %%
# You only need edit the following
input_file = "files/animal_wm_graph.lp"
keyword = "game" # can be either game or arg, depends on the graphviz_settings.json
reverse = False #whether reverse the edge
gvz_version = "unfactored" #"nongrouped" shows the non-grouped version, "clean" shows the grouped one

# %%
generate_graphviz(input_file, keyword, reverse)
Image(f"imgs/{gvz_version}_{keyword}_wfs.png")

# %%
display_images_in_rows(f"{gvz_version}_{keyword}_pw")
# Out:
# <div style="text-align: center;"><div style="display: inline-block; width: auto; margin: 60px;"><img src="imgs/nongrouped_game_pw_2.png" style="width: 100%; height: auto;" alt="PW 2" /><div>PW 2</div></div><div style="display: inline-block; width: auto; margin: 60px;"><img src="imgs/nongrouped_game_pw_1.png" style="width: 100%; height: auto;" alt="PW 1" /><div>PW 1</div></div></div>
