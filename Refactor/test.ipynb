# %%
from gamearg import *
from IPython.display import display, Image

# %%
clear_imgs_folder()

# %%
# You only need edit the following
input_file = "files/animal_wm_graph.lp"
keyword = "arg" 
reverse = False 
gvz_version = "unfactored"

# %%
show_wfs(input_file, keyword, reverse, gvz_version)

# %%
show_stb(input_file, keyword, reverse, gvz_version)
# Out:
# <div style="text-align: center;"><div style="display: inline-block; width: auto; margin: 60px;"><img src="imgs/animal_wm_graph/unfactored_forward_arg_pw_1.png" style="width: 100%; height: auto;" alt="PW pw" /><div>PW pw</div></div><div style="display: inline-block; width: auto; margin: 60px;"><img src="imgs/animal_wm_graph/unfactored_forward_arg_pw_2.png" style="width: 100%; height: auto;" alt="PW pw" /><div>PW pw</div></div></div>
