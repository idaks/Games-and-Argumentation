# %%
from gamearg import *
from IPython.display import display, Image

# %%
input_file = "files/animal_wm_graph.lp"
keyword = "game"
reverse = False

# %%
generate_graphviz(input_file, keyword, reverse)
Image(f"imgs/display_{keyword}_wfs.png")

# %%
display_images_in_rows(f"display_{keyword}_pw")
# Out:
# <div style="text-align: center;"><div style="display: inline-block; width: auto; margin: 60px;"><img src="imgs/display_game_pw_1.png" style="width: 100%; height: auto;" alt="PW 1" /><div>PW 1</div></div><div style="display: inline-block; width: auto; margin: 60px;"><img src="imgs/display_game_pw_2.png" style="width: 100%; height: auto;" alt="PW 2" /><div>PW 2</div></div></div>
