# %%
from gamearg import *
from IPython.display import display, Image

# %% [markdown]
# ## Wild Animal

# %%
input_file = "files/animal_wm_graph.lp"
keyword = "arg" 
reverse = False

# %% [markdown]
# **forward**

# %%
show_wfs(input_file, keyword, reverse)

# %%
show_stb(input_file, keyword,reverse)
# Out:
# <div style="text-align: center;"><div style="display: inline-block; width: auto; margin: 60px;"><img src="imgs/animal_wm_graph/unfactored_forward_arg_pw_1.png" style="width: 100%; height: auto;" alt="PW 1" /><div>PW 1</div></div><div style="display: inline-block; width: auto; margin: 60px;"><img src="imgs/animal_wm_graph/unfactored_forward_arg_pw_2.png" style="width: 100%; height: auto;" alt="PW 2" /><div>PW 2</div></div></div>

# %% [markdown]
# **backward**

# %%
input_file = "files/animal_wm_graph.lp"
keyword = "arg"
reverse = True

# %%
show_wfs(input_file, keyword, reverse)

# %%
show_stb(input_file, keyword, reverse)
# Out:
# <div style="text-align: center;"><div style="display: inline-block; width: auto; margin: 60px;"><img src="imgs/animal_wm_graph/unfactored_backward_arg_pw_1.png" style="width: 100%; height: auto;" alt="PW 1" /><div>PW 1</div></div></div>
