# %%
from gamearg import *
from IPython.display import display, Image

# %%
clear_imgs_folder()

# %% [markdown]
# ## Small Example BL_1

# %%
input_file = "files/wm_graph_bl_1.lp"
keyword = "game" 
reverse = False 
gvz_version = "unfactored"

# %% [markdown]
# **forward**

# %%
show_wfs(input_file, keyword, reverse, gvz_version)

# %%
show_stb(input_file, keyword, gvz_version)
# Out:
# <div style="text-align: center;"><div style="display: inline-block; width: auto; margin: 60px;"><img src="imgs/wm_graph_bl_1/unfactored_game_pw_1.png" style="width: 100%; height: auto;" alt="PW 1" /><div>PW 1</div></div><div style="display: inline-block; width: auto; margin: 60px;"><img src="imgs/wm_graph_bl_1/unfactored_game_pw_2.png" style="width: 100%; height: auto;" alt="PW 2" /><div>PW 2</div></div></div>

# %% [markdown]
# **backward**

# %%
input_file = "files/wm_graph_bl_1.lp"
keyword = "arg"
reverse = False 
gvz_version = "unfactored"

# %%
show_wfs(input_file, keyword, reverse, gvz_version)

# %%
show_stb(input_file, keyword, gvz_version)
# Out:
# <div style="text-align: center;"><div style="display: inline-block; width: auto; margin: 60px;"><img src="imgs/wm_graph_bl_1/unfactored_arg_pw_2.png" style="width: 100%; height: auto;" alt="PW 2" /><div>PW 2</div></div><div style="display: inline-block; width: auto; margin: 60px;"><img src="imgs/wm_graph_bl_1/unfactored_arg_pw_1.png" style="width: 100%; height: auto;" alt="PW 1" /><div>PW 1</div></div></div>

# %% [markdown]
# ## Small Example BL_2

# %% [markdown]
# **forward**

# %%
input_file = "files/wm_graph_bl_2.lp"
keyword = "game"
reverse = False
gvz_version = "unfactored"

# %%
show_wfs(input_file, keyword, reverse, gvz_version)

# %%
show_stb(input_file, keyword, gvz_version)
# Out:
# <div style="text-align: center;"><div style="display: inline-block; width: auto; margin: 60px;"><img src="imgs/wm_graph_bl_2/unfactored_game_pw_1.png" style="width: 100%; height: auto;" alt="PW 1" /><div>PW 1</div></div><div style="display: inline-block; width: auto; margin: 60px;"><img src="imgs/wm_graph_bl_2/unfactored_game_pw_2.png" style="width: 100%; height: auto;" alt="PW 2" /><div>PW 2</div></div></div>

# %% [markdown]
# **backward**

# %%
input_file = "files/wm_graph_bl_2.lp"
keyword = "arg"
reverse = False
gvz_version = "unfactored"

# %%
show_wfs(input_file, keyword, reverse, gvz_version)

# %%
show_stb(input_file, keyword, gvz_version)
# Out:
# <div style="text-align: center;"><div style="display: inline-block; width: auto; margin: 60px;"><img src="imgs/wm_graph_bl_2/unfactored_arg_pw_2.png" style="width: 100%; height: auto;" alt="PW 2" /><div>PW 2</div></div><div style="display: inline-block; width: auto; margin: 60px;"><img src="imgs/wm_graph_bl_2/unfactored_arg_pw_1.png" style="width: 100%; height: auto;" alt="PW 1" /><div>PW 1</div></div></div>

# %% [markdown]
# ## Small Example SB

# %% [markdown]
# **forward**

# %%
input_file = "files/wm_graph_sb.lp"
keyword = "game"
reverse = False
gvz_version = "unfactored"

# %%
show_wfs(input_file, keyword, reverse, gvz_version)

# %%
show_stb(input_file, keyword, gvz_version)
# Out:
# <div style="text-align: center;"><div style="display: inline-block; width: auto; margin: 60px;"><img src="imgs/wm_graph_sb/unfactored_game_pw_1.png" style="width: 100%; height: auto;" alt="PW 1" /><div>PW 1</div></div><div style="display: inline-block; width: auto; margin: 60px;"><img src="imgs/wm_graph_sb/unfactored_game_pw_2.png" style="width: 100%; height: auto;" alt="PW 2" /><div>PW 2</div></div></div>

# %% [markdown]
# **backward**

# %%
input_file = "files/wm_graph_sb.lp"
keyword = "arg"
reverse = False
gvz_version = "unfactored"

# %%
show_wfs(input_file, keyword, reverse, gvz_version)

# %%
show_stb(input_file, keyword, gvz_version)
# Out:
# <div style="text-align: center;"><div style="display: inline-block; width: auto; margin: 60px;"><img src="imgs/wm_graph_sb/unfactored_arg_pw_2.png" style="width: 100%; height: auto;" alt="PW 2" /><div>PW 2</div></div><div style="display: inline-block; width: auto; margin: 60px;"><img src="imgs/wm_graph_sb/unfactored_arg_pw_1.png" style="width: 100%; height: auto;" alt="PW 1" /><div>PW 1</div></div></div>
